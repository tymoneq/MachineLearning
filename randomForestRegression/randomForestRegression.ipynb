# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
dataSet = pd.read_csv("Position_Salaries.csv")

x = dataSet.iloc[:, 1:-1].values
y = dataSet.iloc[:, -1].values

# %%
regressor = RandomForestRegressor(n_estimators=10)

regressor.fit(x,y)
# Out:
# RandomForestRegressor(n_estimators=10)

# %%
print(regressor.predict([[6.5]]))
# Out:
# [155000.]

# %%
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape((len(x_grid)),1)
plt.scatter(x,y)
plt.plot(x_grid, regressor.predict(x_grid))

plt.show()
# Out:
# C:\Users\tymon\AppData\Local\Temp\ipykernel_17708\402228968.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_grid = np.arange(min(x), max(x), 0.1)

# %%
from sklearn.metrics import r2_score

print(r2_score(y,regressor.predict(x)))
# Out:
# 0.9543215692594739
